# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Dell\Downloads\aapl_no_dates.csv")

# %%
df.head(5)
# Out:
#      Open    High     Low   Close    Volume
# 0  153.17  153.33  152.22  153.18  16404088
# 1  153.58  155.45  152.89  155.45  27770715
# 2  154.34  154.45  153.46  153.93  25331662
# 3  153.90  155.81  153.78  154.45  26624926
# 4  155.02  155.98  154.48  155.37  21069647

# %%
df.tail(5)
# Out:
#       Open    High     Low   Close    Volume
# 17  147.17  148.28  145.38  145.82  25692361
# 18  145.01  146.16  143.62  143.73  24761891
# 19  144.49  146.11  143.16  145.83  22082432
# 20  144.71  145.13  142.28  143.68  31499368
# 21  144.45  144.96  143.78  144.02  23024107

# %%
df.shape
# Out:
# (22, 5)

# %%
df.describe()
# Out:
#              Open        High         Low       Close        Volume
# count   22.000000   22.000000   22.000000   22.000000  2.200000e+01
# mean   148.215000  149.088636  146.582727  147.831364  3.109900e+07
# std      4.450871    4.337027    4.507623    4.434315  1.416738e+07
# min    143.320000  144.480000  142.200000  142.270000  1.640409e+07
# 25%    144.785000  146.095000  143.630000  145.047500  2.231785e+07
# 50%    146.320000  147.015000  145.025000  145.850000  2.615864e+07
# 75%    153.477500  154.170000  150.670000  152.130000  3.244740e+07
# max    155.250000  155.980000  154.480000  155.450000  7.230733e+07

# %% [markdown]
# **Gives dates within the start and end dates range, you could also just mention dates without start and end being explicitly written**

# %% [markdown]
# **Also Frequency as 'B' means Business days meaning it will only count Mon to Fri**

# %%
rng = pd.date_range(start="6/1/2016",end="6/30/2016",freq='B')
rng
# Out:
# DatetimeIndex(['2016-06-01', '2016-06-02', '2016-06-03', '2016-06-06',
#                '2016-06-07', '2016-06-08', '2016-06-09', '2016-06-10',
#                '2016-06-13', '2016-06-14', '2016-06-15', '2016-06-16',
#                '2016-06-17', '2016-06-20', '2016-06-21', '2016-06-22',
#                '2016-06-23', '2016-06-24', '2016-06-27', '2016-06-28',
#                '2016-06-29', '2016-06-30'],
#               dtype='datetime64[ns]', freq='B')

# %%
df=df.set_index(rng)
#inplace=True also can be put if you arent mentioning df=, howver if df.set_index('date',inplace=True)  is fine

# %%
df
# Out:
#               Open    High     Low   Close    Volume
# 2016-06-01  153.17  153.33  152.22  153.18  16404088
# 2016-06-02  153.58  155.45  152.89  155.45  27770715
# 2016-06-03  154.34  154.45  153.46  153.93  25331662
# 2016-06-06  153.90  155.81  153.78  154.45  26624926
# 2016-06-07  155.02  155.98  154.48  155.37  21069647
# 2016-06-08  155.25  155.54  154.40  154.99  21250798
# 2016-06-09  155.19  155.19  146.02  148.98  64882657
# 2016-06-10  145.74  146.09  142.51  145.42  72307330
# 2016-06-13  147.16  147.45  145.15  146.59  34165445
# 2016-06-14  147.50  147.50  143.84  145.16  31531232
# 2016-06-15  143.32  144.48  142.21  144.29  32165373
# 2016-06-16  143.78  144.50  142.20  142.27  50361093
# 2016-06-17  143.66  146.74  143.66  146.34  32541404
# 2016-06-20  146.87  146.87  144.94  145.01  24900073
# 2016-06-21  145.52  146.07  144.61  145.87  21265751
# 2016-06-22  145.77  146.70  145.12  145.63  19106294
# 2016-06-23  145.13  147.16  145.11  146.28  35439389
# ...

# %%
df.set_index(rng, inplace=True)
df.head()
# Out:
#               Open    High     Low   Close    Volume
# 2016-06-01  153.17  153.33  152.22  153.18  16404088
# 2016-06-02  153.58  155.45  152.89  155.45  27770715
# 2016-06-03  154.34  154.45  153.46  153.93  25331662
# 2016-06-06  153.90  155.81  153.78  154.45  26624926
# 2016-06-07  155.02  155.98  154.48  155.37  21069647

# %% [markdown]
# **Finding missing dates from datetimeindex**

# %%
daily_index=pd.date_range('6/1/2016','6/30/2016')
daily_index
# Out:
# DatetimeIndex(['2016-06-01', '2016-06-02', '2016-06-03', '2016-06-04',
#                '2016-06-05', '2016-06-06', '2016-06-07', '2016-06-08',
#                '2016-06-09', '2016-06-10', '2016-06-11', '2016-06-12',
#                '2016-06-13', '2016-06-14', '2016-06-15', '2016-06-16',
#                '2016-06-17', '2016-06-18', '2016-06-19', '2016-06-20',
#                '2016-06-21', '2016-06-22', '2016-06-23', '2016-06-24',
#                '2016-06-25', '2016-06-26', '2016-06-27', '2016-06-28',
#                '2016-06-29', '2016-06-30'],
#               dtype='datetime64[ns]', freq='D')

# %%
daily_index.difference(df.index)
# Out:
# DatetimeIndex(['2016-06-04', '2016-06-05', '2016-06-11', '2016-06-12',
#                '2016-06-18', '2016-06-19', '2016-06-25', '2016-06-26'],
#               dtype='datetime64[ns]', freq=None)

# %%
# %matplotlib inline
df['Close'].plot()
# Out:
# <Axes: >

# %%
df["2016-06-01":"2016-06-10"].Close.mean()
# Out:
# 152.72125

# %%
df.Close
# Out:
# 2016-06-01    153.18
# 2016-06-02    155.45
# 2016-06-03    153.93
# 2016-06-06    154.45
# 2016-06-07    155.37
# 2016-06-08    154.99
# 2016-06-09    148.98
# 2016-06-10    145.42
# 2016-06-13    146.59
# 2016-06-14    145.16
# 2016-06-15    144.29
# 2016-06-16    142.27
# 2016-06-17    146.34
# 2016-06-20    145.01
# 2016-06-21    145.87
# 2016-06-22    145.63
# 2016-06-23    146.28
# 2016-06-24    145.82
# 2016-06-27    143.73
# 2016-06-28    145.83
# 2016-06-29    143.68
# 2016-06-30    144.02
# Freq: B, Name: Close, dtype: float64

# %%
df.index
# Out:
# DatetimeIndex(['2016-06-01', '2016-06-02', '2016-06-03', '2016-06-06',
#                '2016-06-07', '2016-06-08', '2016-06-09', '2016-06-10',
#                '2016-06-13', '2016-06-14', '2016-06-15', '2016-06-16',
#                '2016-06-17', '2016-06-20', '2016-06-21', '2016-06-22',
#                '2016-06-23', '2016-06-24', '2016-06-27', '2016-06-28',
#                '2016-06-29', '2016-06-30'],
#               dtype='datetime64[ns]', freq='B')

# %%
df.asfreq('D',method='pad')
# Out:
#               Open    High     Low   Close    Volume
# 2016-06-01  153.17  153.33  152.22  153.18  16404088
# 2016-06-02  153.58  155.45  152.89  155.45  27770715
# 2016-06-03  154.34  154.45  153.46  153.93  25331662
# 2016-06-04  154.34  154.45  153.46  153.93  25331662
# 2016-06-05  154.34  154.45  153.46  153.93  25331662
# 2016-06-06  153.90  155.81  153.78  154.45  26624926
# 2016-06-07  155.02  155.98  154.48  155.37  21069647
# 2016-06-08  155.25  155.54  154.40  154.99  21250798
# 2016-06-09  155.19  155.19  146.02  148.98  64882657
# 2016-06-10  145.74  146.09  142.51  145.42  72307330
# 2016-06-11  145.74  146.09  142.51  145.42  72307330
# 2016-06-12  145.74  146.09  142.51  145.42  72307330
# 2016-06-13  147.16  147.45  145.15  146.59  34165445
# 2016-06-14  147.50  147.50  143.84  145.16  31531232
# 2016-06-15  143.32  144.48  142.21  144.29  32165373
# 2016-06-16  143.78  144.50  142.20  142.27  50361093
# 2016-06-17  143.66  146.74  143.66  146.34  32541404
# ...

# %%
df
# Out:
#               Open    High     Low   Close    Volume
# 2016-06-01  153.17  153.33  152.22  153.18  16404088
# 2016-06-02  153.58  155.45  152.89  155.45  27770715
# 2016-06-03  154.34  154.45  153.46  153.93  25331662
# 2016-06-06  153.90  155.81  153.78  154.45  26624926
# 2016-06-07  155.02  155.98  154.48  155.37  21069647
# 2016-06-08  155.25  155.54  154.40  154.99  21250798
# 2016-06-09  155.19  155.19  146.02  148.98  64882657
# 2016-06-10  145.74  146.09  142.51  145.42  72307330
# 2016-06-13  147.16  147.45  145.15  146.59  34165445
# 2016-06-14  147.50  147.50  143.84  145.16  31531232
# 2016-06-15  143.32  144.48  142.21  144.29  32165373
# 2016-06-16  143.78  144.50  142.20  142.27  50361093
# 2016-06-17  143.66  146.74  143.66  146.34  32541404
# 2016-06-20  146.87  146.87  144.94  145.01  24900073
# 2016-06-21  145.52  146.07  144.61  145.87  21265751
# 2016-06-22  145.77  146.70  145.12  145.63  19106294
# 2016-06-23  145.13  147.16  145.11  146.28  35439389
# ...

# %%
df.asfreq('W',method='pad')
# Out:
#               Open    High     Low   Close    Volume
# 2016-06-05  154.34  154.45  153.46  153.93  25331662
# 2016-06-12  145.74  146.09  142.51  145.42  72307330
# 2016-06-19  143.66  146.74  143.66  146.34  32541404
# 2016-06-26  147.17  148.28  145.38  145.82  25692361

# %%
df.asfreq('H',method='pad')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14320\3367193647.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   df.asfreq('H',method='pad')
#                        Open    High     Low   Close    Volume
# 2016-06-01 00:00:00  153.17  153.33  152.22  153.18  16404088
# 2016-06-01 01:00:00  153.17  153.33  152.22  153.18  16404088
# 2016-06-01 02:00:00  153.17  153.33  152.22  153.18  16404088
# 2016-06-01 03:00:00  153.17  153.33  152.22  153.18  16404088
# 2016-06-01 04:00:00  153.17  153.33  152.22  153.18  16404088
# ...                     ...     ...     ...     ...       ...
# 2016-06-29 20:00:00  144.71  145.13  142.28  143.68  31499368
# 2016-06-29 21:00:00  144.71  145.13  142.28  143.68  31499368
# 2016-06-29 22:00:00  144.71  145.13  142.28  143.68  31499368
# 2016-06-29 23:00:00  144.71  145.13  142.28  143.68  31499368
# 2016-06-30 00:00:00  144.45  144.96  143.78  144.02  23024107
#
# [697 rows x 5 columns]

# %%
rng
# Out:
# DatetimeIndex(['2016-06-01', '2016-06-02', '2016-06-03', '2016-06-06',
#                '2016-06-07', '2016-06-08', '2016-06-09', '2016-06-10',
#                '2016-06-13', '2016-06-14', '2016-06-15', '2016-06-16',
#                '2016-06-17', '2016-06-20', '2016-06-21', '2016-06-22',
#                '2016-06-23', '2016-06-24', '2016-06-27', '2016-06-28',
#                '2016-06-29', '2016-06-30'],
#               dtype='datetime64[ns]', freq='B')

# %% [markdown]
# **generating DatetimeIndex with periods argument**

# %%
rng = pd.date_range('1/1/2011', periods=72, freq='H')
rng
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14320\3019444540.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   rng = pd.date_range('1/1/2011', periods=72, freq='H')
# DatetimeIndex(['2011-01-01 00:00:00', '2011-01-01 01:00:00',
#                '2011-01-01 02:00:00', '2011-01-01 03:00:00',
#                '2011-01-01 04:00:00', '2011-01-01 05:00:00',
#                '2011-01-01 06:00:00', '2011-01-01 07:00:00',
#                '2011-01-01 08:00:00', '2011-01-01 09:00:00',
#                '2011-01-01 10:00:00', '2011-01-01 11:00:00',
#                '2011-01-01 12:00:00', '2011-01-01 13:00:00',
#                '2011-01-01 14:00:00', '2011-01-01 15:00:00',
#                '2011-01-01 16:00:00', '2011-01-01 17:00:00',
#                '2011-01-01 18:00:00', '2011-01-01 19:00:00',
#                '2011-01-01 20:00:00', '2011-01-01 21:00:00',
#                '2011-01-01 22:00:00', '2011-01-01 23:00:00',
# ...

# %%
import numpy as np
ts = pd.Series(np.random.randint(0,10,len(rng)), index=rng)
ts.head(20)
# Out:
# 2011-01-01 00:00:00    4
# 2011-01-01 01:00:00    2
# 2011-01-01 02:00:00    6
# 2011-01-01 03:00:00    8
# 2011-01-01 04:00:00    3
# 2011-01-01 05:00:00    4
# 2011-01-01 06:00:00    4
# 2011-01-01 07:00:00    8
# 2011-01-01 08:00:00    0
# 2011-01-01 09:00:00    6
# 2011-01-01 10:00:00    4
# 2011-01-01 11:00:00    1
# 2011-01-01 12:00:00    5
# 2011-01-01 13:00:00    5
# 2011-01-01 14:00:00    8
# 2011-01-01 15:00:00    7
# 2011-01-01 16:00:00    8
# 2011-01-01 17:00:00    0
# 2011-01-01 18:00:00    2
# 2011-01-01 19:00:00    6
# Freq: h, dtype: int32

# %%
# %matplotlib inline
df['Close'].plot(kind='bar')
# Out:
# <Axes: >
