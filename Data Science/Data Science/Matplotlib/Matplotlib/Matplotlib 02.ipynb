# %% [markdown]
# **<h1>Exploring Matplotlib 02</h1>**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **<h1>Line Graph  (Gas Prices Dataset)</h1>**

# %%
gas = pd.read_csv(r"C:\Users\Dell\Downloads\Data Science Files\Matplotlib Explanation\11_Python_Matplotlib_Module-main\gas_prices.csv")
gas.head()
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA
# 0         2.05  2.82  1.16
# 1         2.49  3.01  1.14
# 2         2.65  3.06  1.13
# 3         2.88  2.84  1.11
# 4         2.87  2.99  1.11

# %%
gas.tail()
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 14  2004       2.72    2.37    4.99     5.24   5.29   3.93    2.03
# 15  2005       3.23    2.89    5.46     5.66   5.74   4.28    2.22
# 16  2006       3.54    3.26    5.88     6.03   6.10   4.47    2.31
# 17  2007       3.85    3.59    6.60     6.88   6.73   4.49    2.40
# 18  2008       4.45    4.08    7.51     7.75   7.63   5.74    2.45
#
#     South Korea    UK   USA
# 14         4.51  5.56  1.88
# 15         5.28  5.97  2.30
# 16         5.92  6.36  2.59
# 17         6.21  7.13  2.80
# 18         5.83  7.42  3.27

# %%
# Settign up the figure size
plt.figure(figsize=(8, 5))

# Adding a title with specified font properties
plt.title('Gas Prices over Time (in USD)', fontdict={'fontweight': 'bold', 'fontsize': 18})

# Plotting gas prices for different countries
plt.plot(gas.Year, gas.USA, color='blue', marker='.', linestyle='-', label='United States')
plt.plot(gas.Year, gas.Canada, color='red', marker='.', linestyle='-', label='Canada')
plt.plot(gas.Year, gas['South Korea'], color='green', marker='.', linestyle='-', label='South Korea')
plt.plot(gas.Year, gas.Australia, color='yellow', marker='.', linestyle='-', label='Australia')


# countries_to_look_at = ['Australia', 'USA', 'Canada', 'South Korea']
# for country in gas:
#     if country in countries_to_look_at:
#         plt.plot(gas.Year, gas[country], marker='.')


# Customizing x-axis's ticks
# Selects every third year and adds 2011 at X ticks
plt.xticks(gas.Year[::3].tolist() + [2011])


plt.xlabel('Year')
plt.ylabel('US Dollars')

# We add a legend to distinguish the lines
plt.legend()

# Save the figure as a high-resolution PNG file
# plt.savefig('Gas_price_figure.png', dpi=300)

plt.show()

# %% [markdown]
# **<h1>FIFA Dataset</h1>**

# %%
fifa = pd.read_csv(r"C:\Users\Dell\Downloads\Data Science Files\Matplotlib Explanation\11_Python_Matplotlib_Module-main\fifa_data.csv")

# %%
fifa.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
fifa.tail()
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 18202  https://cdn.sofifa.org/players/4/19/238813.png     England
# 18203  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 18202  https://cdn.sofifa.org/flags/14.png       47         65
# 18203  https://cdn.sofifa.org/flags/46.png       47         63
# 18204  https://cdn.sofifa.org/flags/14.png       47         67
# ...

# %% [markdown]
# **<h1>Histogram</h1>**

# %%
# custom bin edges for the histogram.
bins = [40,50,60,70,80,90,100]

# specified size of 8x5 inches.
plt.figure(figsize=(8,5))

# ''Overall' is a column in the 'fifa' DataFrame
# The y-axis represents the frequency (count) of players within each bin
plt.hist(fifa.Overall, bins=bins, color='#abcdef')

# plt.xticks(bins)

plt.ylabel('Number of Players')
plt.xlabel('Skill Level')
plt.title('Distribution of Player Skills in FIFA 2018')

# Saving the image
# plt.savefig('histogram.png', dpi=300)

plt.show()

# %% [markdown]
# **<h1>Pie Chart</h1>**

# %% [markdown]
# **A Simple Pie Chart**

# %%
import matplotlib.pyplot as plt

# Data to plot
labels = ['Apples', 'Bananas', 'Cherries', 'Dates']
sizes = [15, 30, 45, 10]
colors = ['red', 'yellow', 'blue', 'brown']
explode = (0.1, 0, 0, 0)  # Explode the 1st slice (Apples)

# Create the pie chart
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)

# Set the title
plt.title('Fruit Distribution')

# Display the pie chart
# Out:
# Text(0.5, 1.0, 'Fruit Distribution')

# %% [markdown]
# **Pie Chart based on FIFA dataset**

# %%
# Filter the DataFrame to include only players with 'Left' as their Preferred Foot,
# count the non-null entries in the filtered DataFrame for each column,
# and then use the index [0] to access the count from the first column

left = fifa.loc[fifa['Preferred Foot'] == 'Left'].count()[0]
right = fifa.loc[fifa['Preferred Foot'] == 'Right'].count()[0]

plt.figure(figsize=(8,5))

labels = ['Left', 'Right']
colors = ['#abcdef', '#aabbcc']


# Create a pie chart with the specified sizes (left and right), labels, and colors.
# Display the percentage values of each pie slice with two decimal places.
# 'autopct' parameter is used to format the percentage values shown on the pie slices.
# '%.2f %%' specifies that percentages should be shown with two decimal places followed by a percentage symbol.

plt.pie([left, right], labels = labels, colors=colors, autopct='%.2f %%')

plt.title('Foot Preference of FIFA Players')

plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_8472\3466077021.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   left = fifa.loc[fifa['Preferred Foot'] == 'Left'].count()[0]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_8472\3466077021.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   right = fifa.loc[fifa['Preferred Foot'] == 'Right'].count()[0]

# %%
plt.figure(figsize=(8,5), dpi=100)

plt.style.use('ggplot')

# Convert the 'Weight' column values from strings with 'lbs' to integers.
# For each value 'x' in 'fifa.Weight', check if 'x' is a string.
# If 'x' is a string, remove the 'lbs' part and convert the remaining part to an integer.
# If 'x' is not a string, keep it as is.

fifa.Weight = [int(x.strip('lbs')) if type(x)==str else x for x in fifa.Weight]

light = fifa.loc[fifa.Weight < 125].count()[0]
light_medium = fifa[(fifa.Weight >= 125) & (fifa.Weight < 150)].count()[0]
medium = fifa[(fifa.Weight >= 150) & (fifa.Weight < 175)].count()[0]
medium_heavy = fifa[(fifa.Weight >= 175) & (fifa.Weight < 200)].count()[0]
heavy = fifa[fifa.Weight >= 200].count()[0]

# List of counts for each weight category
weights = [light, light_medium, medium, medium_heavy, heavy]

# Labels for each weight category
label = ['under 125', '125-150', '150-175', '175-200', 'over 200']

# Explode the first, second and last slices for emphasis
explode = (.4, .2, 0, 0, .4)

# Set the title of the pie chart
plt.title('Weight of Professional Soccer Players (lbs)')

# Create the pie chart
# 'weights' specifies the size of each slice
# 'labels' specifies the labels for each slice
# 'explode' makes the first, second and last slices stand out
# 'pctdistance' sets the distance of the percentage labels from the center
# 'autopct' formats the percentage values with two decimal places
plt.pie(weights, labels=label, explode=explode, pctdistance=0.8, autopct='%.2f %%')

# Display the pie chart
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_8472\3948505059.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   light = fifa.loc[fifa.Weight < 125].count()[0]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_8472\3948505059.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   light_medium = fifa[(fifa.Weight >= 125) & (fifa.Weight < 150)].count()[0]
# ...

# %% [markdown]
# **Pie Chart using Iris dataset**

# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\Dell\Downloads\Data Science Files\Matplotlib Explanation\11_Python_Matplotlib_Module-main\iris_data.csv")
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
SepalLength = data['SepalLengthCm'].value_counts()

SepalLength.plot(kind='pie', title='Sepal Length', figsize=(9,9))
plt.legend()
plt.show()

# %% [markdown]
# **<h1>Box Plot</h1>**

# %%
plt.figure(figsize=(5,8), dpi=100)

plt.style.use('default')

barcelona = fifa.loc[fifa.Club == "FC Barcelona"]['Overall']
madrid = fifa.loc[fifa.Club == "Real Madrid"]['Overall']
revs = fifa.loc[fifa.Club == "New England Revolution"]['Overall']

#bp = plt.boxplot([barcelona, madrid, revs], labels=['a','b','c'], boxprops=dict(facecolor='red'))
bp = plt.boxplot([barcelona, madrid, revs], labels=['FC Barcelona','Real Madrid','NE Revolution'], patch_artist=True, medianprops={'linewidth': 2})

plt.title('Professional Soccer Team Comparison')
plt.ylabel('FIFA Overall Rating')

for box in bp['boxes']:
    # change outline color
    box.set(color='#4286f4', linewidth=2)
    # change fill color
    box.set(facecolor = '#e0e0e0' )
    # change hatch
    #box.set(hatch = '/')
    
plt.show()

# %% [markdown]
# **Box Plot using created dataframe**

# %%
#cateating data
import pandas as pd
df = pd.DataFrame({'Name': ['John', 'Rad', 'Var', 'Mathew', 'Alina', 'Lee', 'Rogers'],
                   'Salary':[60000,64000,60000,289000,66000,50000,60000],
                   'Hours':[41,40,36,30,35,39,40],
                   'Grade':[50,50,46,95,50,5,57]})
print(df)

# Quartiles of Hours
print(df['Hours'].quantile([0.25, 0.5, 0.75]))
# Out:
#      Name  Salary  Hours  Grade
# 0    John   60000     41     50
# 1     Rad   64000     40     50
# 2     Var   60000     36     46
# 3  Mathew  289000     30     95
# 4   Alina   66000     35     50
# 5     Lee   50000     39      5
# 6  Rogers   60000     40     57
# 0.25    35.5
# 0.50    39.0
# 0.75    40.0
# Name: Hours, dtype: float64

# %%
# Plot a box-whisker chart
df['Hours'].plot(kind='box', title='Weekly Hours Distribution', figsize=(10,8))
plt.show()

# %%
# Quartiles of Salary
print(df['Salary'].quantile([0.25, 0.5, 0.75]))

# Plot a box-whisker chart
df['Salary'].plot(kind='box', title='Salary Distribution', figsize=(10,8))
plt.show()
# Out:
# 0.25    60000.0
# 0.50    60000.0
# 0.75    65000.0
# Name: Salary, dtype: float64
